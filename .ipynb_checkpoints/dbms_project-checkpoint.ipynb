# %%
import pandas as pd
import numpy as np
import nltk
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords
nltk.download('punkt')
nltk.download('stopwords')
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
# Out:
# [nltk_data] Downloading package punkt to /Users/saahil/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/saahil/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
courses_df = pd.read_csv('/Users/saahil/Desktop/College/Sem 5/DBMS Lab/Project/coursera_courses.csv')

# job_df.head()

job_df = pd.read_csv('/Users/saahil/Desktop/College/Sem 5/DBMS Lab/Project/job_data_filtered.csv')
# courses_df.head()

# %%
job_df.head()
# Out:
#                                            job_title     category  \
# 0                               Full Stack Developer  Engineering
# 1                           Windows Helpdesk Advisor     Computer
# 2  CB-WLS- Credit Support Specialist Iv- Operatio...   Healthcare
# 3                        Sales Executive-South Delhi    Part time
# 4                           Senior Software Engineer           IT
#
#                        company_name       city        state country  \
# 0                           skilora     Remote    Karnataka      IN
# 1                               IBM  Bengaluru    Karnataka      IN
# 2         JPMorgan Chase Bank, N.A.  Bengaluru    Karnataka      IN
# 3               Rama Panels Pvt Ltd      Delhi        Delhi      IN
# 4  Larsen & Toubro Infotech Limited  Hinjewadi  Maharashtra      IN
#
#                                      job_description           job_type  \
# 0  We are currently looking for a Full Stack Deve...          Full-time
# 1  Introduction A Technical Support Representativ...          Full-time
# 2  Job responsibilities: Review Loan documents an...          Full-time
# 3  Managing existing, Dealers & Sub dealers Devel...  Full-time|Fresher
# 4  "Manual Tester Job Description Skills and Qual...          Full-time
#
#    is_remote
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False

# %%
courses_df.head()
# Out:
#                                         course_title  \
# 0  (ISC)² Systems Security Certified Practitioner...
# 1                           .NET FullStack Developer
# 2  21st Century Energy Transition: how do we make...
# 3  A Crash Course in Causality:  Inferring Causal...
# 4                                   A life with ADHD
#
#           course_organization course_certificate_type   course_time  \
# 0                        ISC2          Specialization  3 - 6 Months
# 1              Board Infinity          Specialization  1 - 3 Months
# 2       University of Alberta                  Course  1 - 3 Months
# 3  University of Pennsylvania                  Course  1 - 3 Months
# 4        University of Geneva                  Course  1 - 3 Months
#
#    course_rating course_reviews_num course_difficulty  \
# 0            4.7                492          Beginner
# 1            4.3                 51      Intermediate
# 2            4.8                 62          Beginner
# 3            4.7                517      Intermediate
# 4            NaN                NaN          Beginner
#
#                                           course_url course_students_enrolled  \
# 0  https://www.coursera.org/specializations/sscp-...                    6,958
# 1  https://www.coursera.org/specializations/dot-n...                    2,531
# 2  https://www.coursera.org/learn/21st-century-en...                    4,377
# 3  https://www.coursera.org/learn/crash-course-in...                   39,004
# 4      https://www.coursera.org/learn/life-with-adhd                      NaN
#
#                                        course_skills  \
# 0  ['Risk Management', 'Access Control', 'Asset',...
# 1  ['Web API', 'Web Development', 'Cascading Styl...
# 2                                                 []
# 3  ['Instrumental Variable', 'Propensity Score Ma...
# 4  ['differential diagnosis and comorbidities', '...
#
#                                       course_summary  \
# 0                                                 []
# 1  ['Master .NET full stack web dev: from .NET co...
# 2  ['Understand the complexity of systems supplyi...
# 3                                                 []
# 4  [' Understand what ADHD is and the challenges ...
#
#                                   course_description
# 0  Pursue better IT security job opportunities an...
# 1  Develop the proficiency required to design and...
# 2  Affordable, abundant and reliable energy is fu...
# 3  We have all heard the phrase “correlation does...
# 4  What is ADHD and what are the challenges that ...

# %%
# Initialize the stemmer
stemmer = PorterStemmer()

stop_words = set(stopwords.words('english'))
# Define a function to stem words in each course description
def stem_text(text):
    if isinstance(text, str):  # Check if the entry is a string
        words = nltk.word_tokenize(text)
        filtered_words = [word for word in words if word.lower() not in stop_words]
        return ' '.join(stemmer.stem(word) for word in filtered_words)
    else:
        return ""  # Return an empty string if it's not a valid string


# Apply the function to the course_description column
courses_df['course_description_stemmed'] = courses_df['course_description'].apply(stem_text)

courses_df.drop(columns = ['course_description'], inplace = True)

# %%
courses_df.head()
# Out:
#                                         course_title  \
# 0  (ISC)² Systems Security Certified Practitioner...
# 1                           .NET FullStack Developer
# 2  21st Century Energy Transition: how do we make...
# 3  A Crash Course in Causality:  Inferring Causal...
# 4                                   A life with ADHD
#
#           course_organization course_certificate_type   course_time  \
# 0                        ISC2          Specialization  3 - 6 Months
# 1              Board Infinity          Specialization  1 - 3 Months
# 2       University of Alberta                  Course  1 - 3 Months
# 3  University of Pennsylvania                  Course  1 - 3 Months
# 4        University of Geneva                  Course  1 - 3 Months
#
#    course_rating course_reviews_num course_difficulty  \
# 0            4.7                492          Beginner
# 1            4.3                 51      Intermediate
# 2            4.8                 62          Beginner
# 3            4.7                517      Intermediate
# 4            NaN                NaN          Beginner
#
#                                           course_url course_students_enrolled  \
# 0  https://www.coursera.org/specializations/sscp-...                    6,958
# 1  https://www.coursera.org/specializations/dot-n...                    2,531
# 2  https://www.coursera.org/learn/21st-century-en...                    4,377
# 3  https://www.coursera.org/learn/crash-course-in...                   39,004
# 4      https://www.coursera.org/learn/life-with-adhd                      NaN
#
#                                        course_skills  \
# 0  ['Risk Management', 'Access Control', 'Asset',...
# 1  ['Web API', 'Web Development', 'Cascading Styl...
# 2                                                 []
# 3  ['Instrumental Variable', 'Propensity Score Ma...
# 4  ['differential diagnosis and comorbidities', '...
#
#                                       course_summary  \
# 0                                                 []
# 1  ['Master .NET full stack web dev: from .NET co...
# 2  ['Understand the complexity of systems supplyi...
# 3                                                 []
# 4  [' Understand what ADHD is and the challenges ...
#
#                           course_description_stemmed
# 0  pursu better secur job opportun prove knowledg...
# 1  develop profici requir design develop comprehe...
# 2  afford , abund reliabl energi fundament human ...
# 3  heard phrase “ correl equal causation. ” , , e...
# 4  adhd challeng come ? whether person affect adh...

# %%
# job_df.head()
job_df['job_description'] = job_df['job_description'].apply(stem_text)

# %%
job_df.head()
# Out:
#                                            job_title     category  \
# 0                               Full Stack Developer  Engineering
# 1                           Windows Helpdesk Advisor     Computer
# 2  CB-WLS- Credit Support Specialist Iv- Operatio...   Healthcare
# 3                        Sales Executive-South Delhi    Part time
# 4                           Senior Software Engineer           IT
#
#                        company_name       city        state country  \
# 0                           skilora     Remote    Karnataka      IN
# 1                               IBM  Bengaluru    Karnataka      IN
# 2         JPMorgan Chase Bank, N.A.  Bengaluru    Karnataka      IN
# 3               Rama Panels Pvt Ltd      Delhi        Delhi      IN
# 4  Larsen & Toubro Infotech Limited  Hinjewadi  Maharashtra      IN
#
#                                      job_description           job_type  \
# 0  current look full stack develop join team . sk...          Full-time
# 1  introduct technic support repres ibm front-lin...          Full-time
# 2  job respons : review loan document process tra...          Full-time
# 3  manag exist , dealer & sub dealer develop new ...  Full-time|Fresher
# 4  `` manual tester job descript skill qualif req...          Full-time
#
#    is_remote
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False

# %%
def vectorise_text(df,col,lang):
  tfidf_vectorizer = TfidfVectorizer(stop_words=lang)
  tfidf_matrix = tfidf_vectorizer.fit_transform(df[col].fillna(''))
  cosine_sim_matrix = cosine_similarity(tfidf_matrix, tfidf_matrix)
  return cosine_sim_matrix

# %%
course_desc_vectorised = vectorise_text(courses_df,'course_description_stemmed','english')
job_desc_vectorised = vectorise_text(job_df,'job_description','english')
